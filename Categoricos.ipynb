# %% [markdown]
# <a href="https://colab.research.google.com/github/tluciad/BeatMaker/blob/main/Categoricos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Categoricos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data=tips,x='day', hue='sex')
plt.show()

# %%
sns.countplot(data=tips,y='day', hue='sex')
plt.show()

# %%
sns.stripplot(data=tips,x='day', hue='sex', y='total_bill', dodge=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips,x='day', hue='sex', y='total_bill', dodge=True)
plt.show()

# %%
sns.boxplot(data=tips,x='day', hue='sex', y='total_bill', dodge=True)
plt.show()

# %%
sns.violinplot(data=tips,x='day', hue='sex', y='total_bill', dodge=True, palette="husl")
plt.show()

# %%
sns.catplot(data=tips,x='day', hue='sex', y='total_bill', dodge=True, palette="husl")
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
car = sns.load_dataset("car_crashes")
car.head(2)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK

# %%
sns.histplot(data=car,x='total', y='alcohol')
plt.show()
